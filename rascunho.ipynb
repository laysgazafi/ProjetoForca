# %%
with open("palavras.txt", encoding='utf8') as arquivo:
    txt = arquivo.readlines()
    lista_palavras = [palavra.replace("\n", "").upper() for palavra in txt]

# %%
lista_palavras
# Out:
# ['AARÃO',
#  'ABEL',
#  'ABELARDO',
#  'ABISSÍNIA',
#  'ABNER',
#  'ABRAÃO',
#  'ABSALÃO',
#  'ACAB',
#  'ACAIA',
#  'ACKER',
#  'ACONCÁGUA',
#  'ACRE',
#  'ACRÓPOLE',
#  'ADAUTO',
#  'ADEMIR',
#  'ADHEMAR',
#  'ADOLFO',
#  'ADRIANA',
#  'ADRIANO',
#  'ADRIÁTICO',
#  'ADROALDO',
#  'AFEGANISTÃO',
#  'AFONSO',
#  'AFRODITE',
#  'AGOSTINHO',
#  'AIRES',
#  'AJAX',
#  'ALAGOAS',
#  'ALAIR',
#  'ALARICO',
#  'ALASCA',
#  'ALBERTA',
#  'ALBERTINA',
#  'ALBERTO',
#  'ALCEU',
#  'ALCIBÍADES',
#  'ALCINO',
#  'ALDEBARÃ',
#  'ALEMANHA',
#  'ALENCAR',
#  'ALEXANDRA',
#  'ALEXANDRE',
#  'ALEXANDRIA',
#  'ALFREDO',
#  'ALGOL',
#  'ALINE',
#  'ALPES',
#  'ALSÁCIA',
#  'ALTAIR',
#  'ALVARENGA',
#  'ALÁ',
#  'AMADEU',
#  'AMAPÁ',
#  'AMAZONAS',
#  'AMAZÔNIA',
#  'AMBRÓSIO',
#  'AMÁLIA',
#  'AMÉRICA',
#  'ANA',
#  'ANASTÁCIA',
#  'ANASTÁCIO',
#  'ANATÓLIA',
#  'ANAXÁGORAS',
#  'ANCARA',
#  'ANDALUZIA',
#  'ANDORRA',
#  'ANDRADE',
#  'ANDRÉ',
#  'ANDRÉA',
#  'ANDRÔMEDA',
#  'ANGOLA',
#  'ANSELMO',
#  'ANTARES',
#  'ANTILHAS',
#  'ANTIOQUIA',
#  'ANTONIETA',
#  'ANTONINA',
#  'ANTONINO',
#  'ANTUÉRPIA',
#  'ANTÁRTICA',
#  'ANTÁRTIDA',
#  'ANTÍOCO',
#  'ANTÔNIA',
#  'ANTÔNIO',
#  'ANÁS',
#  'APARECIDA',
#  'APOLÔNIO',
#  'AQUILES',
#  'AQUITÂNIA',
#  'ARACAJU',
#  'ARAGUAIA',
#  'ARAGÃO',
#  'ARAL',
#  'ARARAT',
#  'AREÓPAGO',
#  'ARGEL',
#  'ARGENTINA',
#  'ARGOS',
#  'ARIADNE',
#  'ARISTARCO',
#  'ARISTIDES',
#  'ARISTÓFANES',
#  'ARISTÓTELES',
#  'ARIZONA',
#  'ARMANDO',
#  'ARMÊNIA',
#  'ARNALDO',
#  'ARTAXERXES',
#  'ARTUR',
#  'ARÁBIA',
#  'ASSUERO',
#  'ATANÁSIO',
#  'AURELIANA',
#  'AURELIANO',
#  'AURÉLIA',
#  'AURÉLIO',
#  'AUSTRÁLIA',
#  'AVERRÓIS',
#  'AVICENA',
#  'AVINHÃO',
#  'AZERBAIJÃO',
#  'AÇORES',
#  'AÉCIO',
#  'BC',
#  'BAAL',
#  'BABEL',
#  'BACO',
#  'BAGDÁ',
#  'BAHAMAS',
#  'BAICAL',
#  'BALAÃO',
#  'BALEARES',
#  'BALTASAR',
#  'BANACH',
#  'BANGLADESH',
#  'BANGU',
#  'BARCELONA',
#  'BARNABÉ',
#  'BARRABÁS',
#  'BARROSO',
#  'BARTOLOMEU',
#  'BARUQUE',
#  'BASTILHA',
#  'BASÍLIO',
#  'BEATRIZ',
#  'BELCHIOR',
#  'BELGRADO',
#  'BELIAL',
#  'BELISÁRIO',
#  'BELIZE',
#  'BELZEBU',
#  'BELÉM',
#  'BENEDITA',
#  'BENEDITO',
#  'BENELUX',
#  'BENEVIDES',
#  'BENJAMIM',
#  'BENTO',
#  'BERENICE',
#  'BERING',
#  'BERLIM',
#  'BERLOQUE',
#  'BERMUDAS',
#  'BERNA',
#  'BERNARDINO',
#  'BERNARDO',
#  'BERNOULLI',
#  'BERTA',
#  'BETELGEUSE',
#  'BETÂNIA',
#  'BIELO',
#  'BILBAO',
#  'BISSAU',
#  'BISÂNCIO',
#  'BOAVENTURA',
#  'BOLONHA',
#  'BOMBAIM',
#  'BONIFÁCIO',
#  'BORBA',
#  'BORNÉU',
#  'BOTSUANA',
#  'BOTSWANA',
#  'BRABANTE',
#  'BRAMAPUTRA',
#  'BRANDENBURGO',
#  'BRASIL',
#  'BRASÍLIA',
#  'BRETANHA',
#  'BRUGES',
#  'BRUNO',
#  'BRUXELAS',
#  'BRÍGIDA',
#  'BRÍSTOL',
#  'BUCARESTE',
#  'BUDAPESTE',
#  'BUENOS',
#  'BURUNDI',
#  'BÉLGICA',
#  'BÓSFORO',
#  'BÓSNIA',
#  'CNPQ',
#  'CABRAL',
#  'CAMPINAS',
#  'CANABIS',
#  'CANADÁ',
#  'CANOPUS',
#  'CAPADÓCIA',
#  'CAPITÓLIO',
#  'CARLA',
#  'CARLINHOS',
#  'CARLOS',
#  'CARMEM',
#  'CAROLINA',
#  'CATARINA',
#  'CAUCHY',
#  'CAVALLIERI',
#  'CAXIAS',
#  'CAYLEY',
#  'CEARÁ',
#  'CECÍLIA',
#  'CELESTINA',
#  'CELESTINO',
#  'CESARÉIA',
#  'CHICA',
#  'CHICAGO',
#  'CHICO',
#  'CHILE',
#  'CHINA',
#  'CHIPRE',
#  'CIBELE',
#  'CIPRIANO',
#  'CIRILO',
#  'CIRO',
#  'CLÁUDIA',
#  'CLÁUDIO',
#  'COIMBRA',
#  'COLÔMBIA',
#  'CONSTANTINOPLA',
#  'COPACABANA',
#  'CORUMBÁ',
#  'COUTO',
#  'CRISTIANO',
#  'CRISTINA',
#  'CRISTO',
#  'CROÁCIA',
#  'CUBA',
#  'CÁTIA',
#  'CÉSAR',
#  'DAFNE',
#  'DAGOBERTO',
#  'DALILA',
#  'DALMÁCIA',
#  'DAMASCO',
#  'DAMIÃO',
#  'DANIEL',
#  'DANIELA',
#  'DANÚBIO',
#  'DARCI',
#  'DARDANELOS',
#  'DARIO',
#  'DAVI',
#  'DAVID',
#  'DECAMERÃO',
#  'DECÁPOLE',
#  'DEDEKIND',
#  'DEJANIRA',
#  'DELFIM',
#  'DELFOS',
#  'DEMÉTRIO',
#  'DEMÓCRITO',
#  'DEMÓSTENES',
#  'DENIS',
#  'DENISE',
#  'DESDÊMONA',
#  'DESIDÉRIO',
#  'DEUCALIÃO',
#  'DEUTERONÔMIO',
#  'DIANA',
#  'DIDO',
#  'DIESEL',
#  'DINAMARCA',
#  'DIOCLECIANO',
#  'DIODORO',
#  'DIOFANTO',
#  'DION',
#  'DIONISO',
#  'DIONÍSIO',
#  'DIOSCUROS',
#  'DIÓGENES',
#  'DOMICIANA',
#  'DOMICIANO',
#  'DOMINGAS',
#  'DOMINGOS',
#  'DOMINICANA',
#  'DOPPLER',
#  'DUNQUERQUE',
#  'DÁCIA',
#  'DÁFNIS',
#  'DÂMOCLES',
#  'DÉBORA',
#  'DÉDALO',
#  'EUA',
#  'EDGAR',
#  'EDIMBURGO',
#  'EDITE',
#  'EDMUNDO',
#  'EFRAIM',
#  'EFRATA',
#  'EGEU',
#  'EGITO',
#  'EIFFEL',
#  'ELDORADO',
#  'ELECTRA',
#  'ELEFANTINA',
#  'ELEONORA',
#  'ELETROBRÁS',
#  'ELIANA',
#  'ELIANE',
#  'ELIAS',
#  'ELIEZER',
#  'ELISA',
#  'ELISABETE',
#  'ELIXA',
#  'ELON',
#  'ELVIRA',
#  'ELÊUSIS',
#  'ELÍGIO',
#  'ELÍSIO',
#  'EMA',
#  'EMANUEL',
#  'EMANUELA',
#  'EMAÚS',
#  'EMILIANA',
#  'EMILIANO',
#  'EMIRADOS',
#  'EMPÉDOCLES',
#  'EMÉRICO',
#  'EMÍLIA',
#  'EMÍLIO',
#  'ENEIDA',
#  'ENGELS',
#  'ENÉIAS',
#  'EPAMINONDAS',
#  'EPICTETO',
#  'EPICURO',
#  'EPIDAURO',
#  'EPIFANIA',
#  'EQUADOR',
#  'ERASMO',
#  'ERATÓSTENES',
#  'ERNESTO',
#  'EROS',
#  'ERZEGÓVINA',
#  'ESAÚ',
#  'ESCANDINÁVIA',
#  'ESCULÁPIO',
#  'ESCÓCIA',
#  'ESLOVÁQUIA',
#  'ESOPO',
#  'ESPANHA',
#  'ESPINHAÇO',
#  'ESPÍRITO',
#  'ESTADOS',
#  'ESTER',
#  'ESTRASBURGO',
#  'ESTREITO',
#  'ESTÊVÃO',
#  'ETIÓPIA',
#  'ETNA',
#  'ETRÚRIA',
#  'EUCLIDES',
#  'EUDÓXIA',
#  'EUDÓXIO',
#  'EUFRATES',
#  'EUGÊNIA',
#  'EUGÊNIO',
#  'EULER',
#  'EULÁLIA',
#  'EUROPA',
#  'EURÁSIA',
#  'EURÍDICE',
#  'EURÍPIDES',
#  'EUSTÁQUIO',
#  'EVA',
#  'EVARISTE',
#  'EVEREST',
#  'EXTREMO',
#  'EZEQUIEL',
#  'EZRA',
#  'FEITOSA',
#  'FELIPE',
#  'FERMAT',
#  'FERNANDA',
#  'FERNANDO',
#  'FILHO',
#  'FILIPINAS',
#  'FINLÂNDIA',
#  'FLANDRES',
#  'FLORIANO',
#  'FLORIANÓPOLIS',
#  'FLÁVIA',
#  'FLÁVIO',
#  'FORTALEZA',
#  'FOURIER',
#  'FRANCISCA',
#  'FRANCISCO',
#  'FRANÇA',
#  'FÁBIO',
#  'FÁTIMA',
#  'GABRIEL',
#  'GALES',
#  'GALOIS',
#  'GARCIA',
#  'GAUSS',
#  'GENEBRA',
#  'GEORGE',
#  'GERAIS',
#  'GERALDO',
#  'GEÓRGIA',
#  'GIRALDO',
#  'GLÓRIA',
#  'GOIÁS',
#  'GOIÂNIA',
#  'GOLFO',
#  'GONZAGA',
#  'GONÇALVES',
#  'GRANDE',
#  'GREGÓRIO',
#  'GROENLÂNDIA',
#  'GRÃ',
#  'GRÉCIA',
#  'GUIANA',
#  'GUILHERME',
#  'GÓLGOTA',
#  'HIV',
#  'HAIA',
#  'HAMBURG',
#  'HAMILTON',
#  'HEGEL',
#  'HELVÉCIO',
#  'HERALDO',
#  'HERÁCLITO',
#  'HILBERT',
#  'HITLER',
#  'HOLANDA',
#  'HORIZONTE',
#  'HUNGRIA',
#  'IBM',
#  'IM',
#  'IMPA',
#  'INDOCHINA',
#  'INDONÉSIA',
#  'INGLATERRA',
#  'INTEL',
#  'INÊS',
#  'IORQUE',
#  'IRLANDA',
#  'IRÃ',
#  'ISLÂNDIA',
#  'ISRAEL',
#  'ISTAMBUL',
#  'ITAMAR',
#  'ITÁLIA',
#  'IUGOSLÁVIA',
#  'JAIME',
#  'JAMAICA',
#  'JAPÃO',
#  'JAVA',
#  'JAVÉ',
#  'JEAN',
#  'JESUS',
#  'JOAQUIM',
#  'JOBIM',
#  'JORDAN',
#  'JORGE',
#  'JOSÉ',
#  'JOÃO',
#  'JOÃOZINHO',
#  'JUNIOR',
#  'JÚPITER',
#  'KAZUO',
#  'KIOTO',
#  'KLEIN',
#  'LABMA',
#  'LAGES',
#  'LAOS',
#  'LAPLACE',
#  'LAPÔNIA',
#  'LATINA',
#  'LAURA',
#  'LAURO',
#  'LEANDRO',
#  'LEBESGUE',
#  'LEIBNITZ',
#  'LENIN',
#  'LETÍCIA',
#  'LETÔNIA',
#  'LINDA',
#  'LINUS',
#  'LINUX',
#  'LISANDRO',
#  'LISBOA',
#  'LISIEUX',
#  'LITUÂNIA',
#  'LONDRES',
#  'LUIZ',
#  'LUÍS',
#  'LÍBANO',
#  'LÚCIFER',
#  'LÚCIO',
#  'MDC',
#  'MERCOSUL',
#  'MACEIÓ',
#  'MADRID',
#  'MALBA',
#  'MALÁSIA',
#  'MANAUS',
#  'MANCHA',
#  'MANHATTAN',
#  'MANOEL',
#  'MANOELA',
#  'MANUEL',
#  'MAR',
#  'MARCELO',
#  'MARCO',
#  'MARCOS',
#  'MARGARETE',
#  'MARGARIDA',
#  'MARGARIDO',
#  'MARIA',
#  'MARICÁ',
#  'MARROCOS',
#  'MARTA',
#  'MARTE',
#  'MARX',
#  'MARY',
#  'MARÍLIA',
#  'MASCARENHAS',
#  'MAURO',
#  'MAURÍCIO',
#  'MEDEIROS',
#  'MEDITERRÂNEO',
#  'MENO',
#  'MERIDIONAL',
#  'MIAMI',
#  'MIGUEL',
#  'MILTON',
#  'MINAS',
#  'MINOTAURO',
#  'MOISÉS',
#  'MONALISA',
#  'MONALISAS',
#  'MORGADO',
#  'MORSE',
#  'MÁRCIA',
#  'MÁRIO',
#  'MÉDIA',
#  'MÉRCURIO',
#  'MÉXICO',
#  'NAIR',
#  'NAPOLEÃO',
#  'NATAL',
#  'NAVIER',
#  'NELSON',
#  'NEUSA',
#  'NEWTOM',
#  'NEWTON',
#  'NICARÁGUA',
#  'NILO',
#  'NINA',
#  'NITERÓI',
#  'NOBEL',
#  'NORONHA',
#  'NORTE',
#  'NORUEGA',
#  'NOVA',
#  'NÁPOLES',
#  'OCEANO',
#  'OGUM',
#  'OHM',
#  'OKLAHOMA',
#  'OSVALDO',
#  'PACÍFICO',
#  'PAI',
#  'PALESTINA',
#  'PALUMBO',
#  'PANAMÁ',
#  'PAQUISTÃO',
#  'PARAGUAI',
#  'PARANÁ',
#  'PARIS',
#  'PARÁ',
#  'PASCAL',
#  'PAULA',
#  'PAULO',
#  'PEANO',
#  'PEDRINHO',
#  'PEDRO',
#  'PENTECOSTES',
#  'PENÉLOPE',
#  'PEQUIM',
#  'PERNAMBUCO',
#  'PETROBRÁS',
#  'PETRÓPOLIS',
#  'PIAUÍ',
#  'PIRINEUS',
#  'PITÁGORAS',
#  'POLÔNIA',
#  'PORTO',
#  'PORTUGAL',
#  'PRAGA',
#  'PRÚSSIA',
#  'PTOLOMEU',
#  'PÁSCOA',
#  'QUADRIVIUM',
#  'QUARUP',
#  'QUIXOTE',
#  'QUÊNIA',
#  'RAFAEL',
#  'RAIMUNDO',
#  'RAMOS',
#  'RAQUEL',
#  'REBECA',
#  'RECIFE',
#  'REINALDO',
#  'RENO',
#  'RIBEIRO',
#  'RICARDA',
#  'RICARDO',
#  'RIO',
#  'RITA',
#  'RIVALDO',
#  'ROBERTO',
#  'ROCHOSAS',
#  'RODRIGUES',
#  'RODÉSIA',
#  'ROGÉRIO',
#  'ROMA',
#  'ROMEU',
#  'ROMÊNIA',
#  'RONALDO',
#  'RONDÔNIA',
#  'RORAIMA',
#  'ROSA',
#  'ROSE',
#  'ROUEN',
#  'RUBENS',
#  'RUBICÃO',
#  'RUTE',
#  'RÁBANO',
#  'RÚSSIA',
#  'SBM',
#  'SAARA',
#  'SALOMÃO',
#  'SALVADOR',
#  'SAMARIA',
#  'SANDRA',
#  'SANDRO',
#  'SANTA',
#  'SANTO',
#  'SANTOS',
#  'SARDENHA',
#  'SATANÁS',
#  'SATIVA',
#  'SATÃ',
#  'SAUDITA',
#  'SENEGAL',
#  'SERGIPE',
#  'SETÚBAL',
#  'SEVILHA',
#  'SIBÉRIA',
#  'SICÍLIA',
#  'SILVA',
#  'SIRIUS',
#  'SIÃO',
#  'SOBOLEV',
#  'SOFONIAS',
#  'SOMÁLIA',
#  'SORAIA',
#  'SOUZA',
#  'SOVIÉTICA',
#  'SPINOSA',
#  'STALIN',
#  'STOKES',
#  'SUL',
#  'SUZANA',
#  'SUÉCIA',
#  'SUÍÇA',
#  'SÁ',
#  'SÃO',
#  'SÉRGIO',
#  'SÍLVIO',
#  'SÍRIA',
#  'SÓCRATES',
#  'SÔNIA',
#  'TV',
#  'TAILÂNDIA',
#  'TAPAJÓS',
#  'TAYLOR',
#  'TCHECOSLOVÁQUIA',
#  'TEODORO',
#  'TERESA',
#  'TERESINA',
#  'TERRA',
#  'TEXAS',
#  'TIBETE',
#  'TOCANTINS',
#  'TOMÁS',
#  'TORONTO',
#  'TORVALDS',
#  'TRIVIUM',
#  'TROTSKY',
#  'TURQUIA',
#  'TÂMISA',
#  'TÓQUIO',
#  'UFRJ',
#  'URSS',
#  'ULISSES',
#  'ULYSSES',
#  'UNIDAS',
#  'UNIDOS',
#  'UNIX',
#  'UNIÃO',
#  'URUGUAI',
#  'UTAH',
#  'VARIG',
#  'VACARIA',
#  'VALDEMAR',
#  'VARSÓVIA',
#  'VATICANO',
#  'VEGAS',
#  'VENEZA',
#  'VENEZUELA',
#  'VERBO',
#  'VERMELHO',
#  'VICTOR',
#  'VIENA',
#  'VIETNÃ',
#  'VIRGÍLIA',
#  'VIRGÍLIO',
#  'VIRGÍNIA',
#  'VISTA',
#  'VITÓRIA',
#  'VÊNUS',
#  'WATERLOO',
#  'YORK',
#  'ZAIR',
#  'ZANETE',
#  'ZELÂNDIA',
#  'ZÂMBIA',
#  'ZÉ',
#  'ZÉFIRO',
#  'A',
#  'ABA',
#  'ABACATE',
#  'ABACATEIRO',
#  'ABACATEIROS',
#  'ABACATES',
#  'ABACAXI',
#  'ABACAXIS',
#  'ABACIAIS',
#  'ABACIAL',
#  'ABADE',
#  'ABADES',
#  'ABADESSA',
#  'ABADESSAS',
#  'ABADIA',
#  'ABADIAS',
#  'ABAFA',
#  'ABAFADA',
#  'ABAFADAS',
#  'ABAFADIÇA',
#  'ABAFADIÇAS',
#  'ABAFADIÇO',
#  'ABAFADIÇOS',
#  'ABAFADO',
#  'ABAFADOS',
#  'ABAFAI',
#  'ABAFAIS',
#  'ABAFAM',
#  'ABAFAMENTO',
#  'ABAFAMENTOS',
#  'ABAFAMO',
#  'ABAFAMOS',
#  'ABAFANDO',
#  'ABAFAR',
#  'ABAFARA',
#  'ABAFARAM',
#  'ABAFARAS',
#  'ABAFARDES',
#  'ABAFAREI',
#  'ABAFAREIS',
#  'ABAFAREM',
#  'ABAFAREMO',
#  'ABAFAREMOS',
#  'ABAFARES',
#  'ABAFARIA',
#  'ABAFARIAM',
#  'ABAFARIAS',
#  'ABAFARMO',
#  'ABAFARMOS',
#  'ABAFARÁ',
#  'ABAFARÁS',
#  'ABAFARÃO',
#  'ABAFARÍAMOS',
#  'ABAFARÍEIS',
#  'ABAFAS',
#  'ABAFASSE',
#  'ABAFASSEM',
#  'ABAFASSES',
#  'ABAFASTE',
#  'ABAFASTES',
#  'ABAFAVA',
#  'ABAFAVAM',
#  'ABAFAVAS',
#  'ABAFE',
#  'ABAFEI',
#  'ABAFEIS',
#  'ABAFEM',
#  'ABAFEMO',
#  'ABAFEMOS',
#  'ABAFES',
#  'ABAFO',
#  'ABAFOU',
#  'ABAFÁ',
#  'ABAFÁRAMOS',
#  'ABAFÁREIS',
#  'ABAFÁSSEIS',
#  'ABAFÁSSEMOS',
#  'ABAFÁVAMOS',
#  'ABAFÁVEIS',
#  'ABAIXA',
#  'ABAIXADA',
#  'ABAIXADAS',
#  'ABAIXADO',
#  'ABAIXADOS',
#  'ABAIXAI',
#  'ABAIXAIS',
#  'ABAIXAM',
#  'ABAIXAMO',
#  'ABAIXAMOS',
#  'ABAIXANDO',
#  'ABAIXAR',
#  'ABAIXARA',
#  'ABAIXARAM',
#  'ABAIXARAS',
#  'ABAIXARDES',
#  'ABAIXAREI',
#  'ABAIXAREIS',
#  'ABAIXAREM',
#  'ABAIXAREMO',
#  'ABAIXAREMOS',
#  'ABAIXARES',
#  'ABAIXARIA',
#  'ABAIXARIAM',
#  'ABAIXARIAS',
#  'ABAIXARMO',
#  'ABAIXARMOS',
#  'ABAIXARÁ',
#  'ABAIXARÁS',
#  'ABAIXARÃO',
#  'ABAIXARÍAMOS',
#  'ABAIXARÍEIS',
#  'ABAIXAS',
#  'ABAIXASSE',
#  'ABAIXASSEM',
#  'ABAIXASSES',
#  'ABAIXASTE',
#  'ABAIXASTES',
#  'ABAIXAVA',
#  'ABAIXAVAM',
#  'ABAIXAVAS',
#  'ABAIXE',
#  'ABAIXEI',
#  'ABAIXEIS',
#  'ABAIXEM',
#  'ABAIXEMO',
#  'ABAIXEMOS',
#  'ABAIXES',
#  'ABAIXO',
#  'ABAIXOU',
#  'ABAIXÁ',
#  'ABAIXÁRAMOS',
#  'ABAIXÁREIS',
#  'ABAIXÁSSEIS',
#  'ABAIXÁSSEMOS',
#  'ABAIXÁVAMOS',
#  'ABAIXÁVEIS',
#  'ABALA',
#  'ABALADA',
#  'ABALADAS',
#  'ABALADO',
#  'ABALADOS',
#  'ABALAI',
#  'ABALAIS',
#  'ABALAM',
#  'ABALAMO',
#  'ABALAMOS',
#  'ABALANCE',
#  'ABALANCEI',
#  'ABALANCEIS',
#  'ABALANCEM',
#  'ABALANCEMO',
#  'ABALANCEMOS',
#  'ABALANCES',
#  'ABALANDO',
#  'ABALANÇA',
#  'ABALANÇADO',
#  'ABALANÇAI',
#  'ABALANÇAIS',
#  'ABALANÇAM',
#  'ABALANÇAMO',
#  'ABALANÇAMOS',
#  'ABALANÇANDO',
#  'ABALANÇAR',
#  'ABALANÇARA',
#  'ABALANÇARAM',
#  'ABALANÇARAS',
#  'ABALANÇARDES',
#  'ABALANÇAREI',
#  'ABALANÇAREIS',
#  'ABALANÇAREM',
#  'ABALANÇAREMO',
#  'ABALANÇAREMOS',
#  'ABALANÇARES',
#  'ABALANÇARIA',
#  'ABALANÇARIAM',
#  'ABALANÇARIAS',
#  'ABALANÇARMO',
#  'ABALANÇARMOS',
#  'ABALANÇARÁ',
#  'ABALANÇARÁS',
#  'ABALANÇARÃO',
#  'ABALANÇARÍAMOS',
#  'ABALANÇARÍEIS',
#  'ABALANÇAS',
#  'ABALANÇASSE',
#  'ABALANÇASSEM',
#  'ABALANÇASSES',
#  'ABALANÇASTE',
#  'ABALANÇASTES',
#  'ABALANÇAVA',
#  'ABALANÇAVAM',
#  'ABALANÇAVAS',
#  'ABALANÇO',
#  'ABALANÇOU',
#  'ABALANÇÁ',
#  'ABALANÇÁRAMOS',
#  'ABALANÇÁREIS',
#  'ABALANÇÁSSEIS',
#  'ABALANÇÁSSEMOS',
#  'ABALANÇÁVAMOS',
#  'ABALANÇÁVEIS',
#  'ABALAR',
#  'ABALARA',
#  'ABALARAM',
#  'ABALARAS',
#  'ABALARDES',
#  'ABALAREI',
#  'ABALAREIS',
#  'ABALAREM',
#  'ABALAREMO',
#  'ABALAREMOS',
#  'ABALARES',
#  'ABALARIA',
#  'ABALARIAM',
#  'ABALARIAS',
#  'ABALARMO',
#  'ABALARMOS',
#  'ABALARÁ',
#  'ABALARÁS',
#  'ABALARÃO',
#  'ABALARÍAMOS',
#  'ABALARÍEIS',
#  'ABALAS',
#  'ABALASSE',
#  'ABALASSEM',
#  'ABALASSES',
#  'ABALASTE',
#  'ABALASTES',
#  'ABALAVA',
#  'ABALAVAM',
#  'ABALAVAS',
#  'ABALE',
#  'ABALEI',
#  'ABALEIS',
#  'ABALEM',
#  'ABALEMO',
#  'ABALEMOS',
#  'ABALES',
#  'ABALIZA',
#  'ABALIZADO',
#  'ABALIZAI',
#  'ABALIZAIS',
#  'ABALIZAM',
#  'ABALIZAMO',
#  'ABALIZAMOS',
#  'ABALIZANDO',
#  'ABALIZAR',
#  'ABALIZARA',
#  ...]

# %%
set("ARRUMAR")
# Out:
# {'A', 'M', 'R', 'U'}

# %%
palavra_secreta = 'EMPOWERDATA'
letras_palavra_secreta = set(palavra_secreta)
print(palavra_secreta)
print(letras_palavra_secreta)

palpites = set()
acertos = set()
# Out:
# EMPOWERDATA
# {'T', 'W', 'M', 'P', 'D', 'O', 'R', 'E', 'A'}

# %%
acertos.add("E")

# %%
painel = [letra if letra in acertos else '_' for letra in palavra_secreta]
print(' '.join(painel))
# Out:
# E _ _ _ _ E _ _ _ _ _
